# %% [markdown]
# # Всем привет! Сейчас я вам покажу свое решение задачи №1

# %% [markdown]
# ## Задача:
# ### Сохрани в переменные n_col и n_row количество столбцов и строк в датафрейме соответственно.

# %%
import pandas as pd
play_store = pd.read_csv("playstore_2.csv")

# %% [markdown]
# ## Для начало я открыл таблицу playstore

# %%
play_store
# Out:
#        Unnamed: 0                                                App  \
# 0               0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1               1                                Coloring book moana
# 2               2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3               3                              Sketch - Draw & Paint
# 4               4              Pixel Draw - Number Art Coloring Book
# ...           ...                                                ...
# 10835       10835                                   Sya9a Maroc - FR
# 10836       10836                   Fr. Mike Schmitz Audio Teachings
# 10837       10837                             Parkinson Exercices FR
# 10838       10838                      The SCP Foundation DB fr nn5n
# 10839       10839      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                   Category  Rating  Reviews                Size     Installs  \
# ...

# %% [markdown]
# ## Решение:

# %%
a=play_store.columns
print(a)
# Out:
# Index(['Unnamed: 0', 'App', 'Category', 'Rating', 'Reviews', 'Size',
#        'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated',
#        'Current Ver', 'Android Ver'],
#       dtype='object')

# %%
n_col= len(a)
print(n_col)
# Out:
# 14

# %%
b = play_store
n_row= len(b)
print(n_row)
# Out:
# 10840

# %% [markdown]
# ### Ответ: 14 , 10840 ✔
